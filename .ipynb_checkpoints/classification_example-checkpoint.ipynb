# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
a = []
b = ['A','B','C','D']
for i in range(768):
    n = np.random.randint(0,4)
    a.append(b[n])

# %%
a
# Out:
# ['B',
#  'B',
#  'C',
#  'A',
#  'A',
#  'C',
#  'B',
#  'A',
#  'B',
#  'C',
#  'A',
#  'C',
#  'B',
#  'B',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'B',
#  'A',
#  'C',
#  'B',
#  'D',
#  'C',
#  'A',
#  'A',
#  'A',
#  'C',
#  'D',
#  'A',
#  'A',
#  'C',
#  'B',
#  'B',
#  'B',
#  'B',
#  'D',
#  'D',
#  'D',
#  'D',
#  'C',
#  'B',
#  'C',
#  'B',
#  'D',
#  'A',
#  'C',
#  'B',
#  'D',
#  'D',
#  'C',
#  'D',
#  'C',
#  'D',
#  'C',
#  'A',
#  'B',
#  'A',
#  'B',
#  'C',
#  'C',
#  'B',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'A',
#  'C',
#  'A',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'A',
#  'C',
#  'C',
#  'D',
#  'D',
#  'B',
#  'D',
#  'D',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'C',
#  'C',
#  'A',
#  'B',
#  'B',
#  'B',
#  'D',
#  'D',
#  'C',
#  'B',
#  'D',
#  'C',
#  'D',
#  'D',
#  'C',
#  'D',
#  'C',
#  'A',
#  'A',
#  'A',
#  'B',
#  'D',
#  'A',
#  'B',
#  'C',
#  'D',
#  'B',
#  'A',
#  'D',
#  'C',
#  'A',
#  'D',
#  'D',
#  'B',
#  'C',
#  'C',
#  'B',
#  'A',
#  'D',
#  'C',
#  'B',
#  'A',
#  'C',
#  'A',
#  'B',
#  'D',
#  'D',
#  'C',
#  'A',
#  'C',
#  'C',
#  'A',
#  'D',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
#  'C',
#  'A',
#  'C',
#  'B',
#  'D',
#  'D',
#  'C',
#  'D',
#  'C',
#  'D',
#  'C',
#  'A',
#  'B',
#  'A',
#  'D',
#  'D',
#  'A',
#  'D',
#  'D',
#  'B',
#  'D',
#  'B',
#  'D',
#  'B',
#  'C',
#  'A',
#  'D',
#  'C',
#  'C',
#  'B',
#  'C',
#  'D',
#  'B',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'B',
#  'A',
#  'C',
#  'D',
#  'C',
#  'C',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'B',
#  'C',
#  'A',
#  'C',
#  'A',
#  'C',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'D',
#  'A',
#  'B',
#  'D',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'D',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'D',
#  'C',
#  'B',
#  'D',
#  'D',
#  'B',
#  'C',
#  'D',
#  'B',
#  'B',
#  'A',
#  'B',
#  'D',
#  'A',
#  'C',
#  'B',
#  'C',
#  'C',
#  'B',
#  'C',
#  'A',
#  'A',
#  'D',
#  'C',
#  'A',
#  'C',
#  'A',
#  'B',
#  'C',
#  'C',
#  'A',
#  'D',
#  'B',
#  'A',
#  'C',
#  'A',
#  'A',
#  'A',
#  'B',
#  'D',
#  'B',
#  'C',
#  'D',
#  'A',
#  'D',
#  'C',
#  'D',
#  'B',
#  'A',
#  'C',
#  'A',
#  'B',
#  'B',
#  'D',
#  'D',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'C',
#  'A',
#  'D',
#  'B',
#  'D',
#  'C',
#  'D',
#  'B',
#  'A',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'D',
#  'A',
#  'C',
#  'B',
#  'D',
#  'A',
#  'D',
#  'B',
#  'D',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'D',
#  'B',
#  'A',
#  'D',
#  'C',
#  'A',
#  'C',
#  'C',
#  'A',
#  'D',
#  'A',
#  'B',
#  'B',
#  'D',
#  'A',
#  'C',
#  'D',
#  'C',
#  'C',
#  'A',
#  'C',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'C',
#  'C',
#  'D',
#  'B',
#  'A',
#  'C',
#  'D',
#  'D',
#  'A',
#  'B',
#  'A',
#  'D',
#  'D',
#  'A',
#  'D',
#  'A',
#  'A',
#  'A',
#  'D',
#  'D',
#  'D',
#  'D',
#  'D',
#  'B',
#  'C',
#  'D',
#  'C',
#  'C',
#  'A',
#  'D',
#  'D',
#  'B',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'A',
#  'B',
#  'D',
#  'D',
#  'A',
#  'D',
#  'B',
#  'C',
#  'D',
#  'C',
#  'A',
#  'D',
#  'D',
#  'D',
#  'A',
#  'C',
#  'D',
#  'D',
#  'B',
#  'A',
#  'D',
#  'A',
#  'D',
#  'C',
#  'D',
#  'A',
#  'A',
#  'B',
#  'C',
#  'C',
#  'C',
#  'A',
#  'C',
#  'A',
#  'C',
#  'D',
#  'D',
#  'B',
#  'C',
#  'A',
#  'A',
#  'C',
#  'D',
#  'A',
#  'B',
#  'A',
#  'C',
#  'C',
#  'D',
#  'D',
#  'D',
#  'B',
#  'B',
#  'C',
#  'A',
#  'C',
#  'D',
#  'C',
#  'C',
#  'A',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'A',
#  'C',
#  'A',
#  'A',
#  'D',
#  'B',
#  'C',
#  'A',
#  'A',
#  'C',
#  'B',
#  'D',
#  'C',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'C',
#  'C',
#  'A',
#  'D',
#  'C',
#  'D',
#  'B',
#  'B',
#  'A',
#  'D',
#  'A',
#  'D',
#  'D',
#  'B',
#  'B',
#  'D',
#  'D',
#  'A',
#  'C',
#  'B',
#  'B',
#  'A',
#  'C',
#  'D',
#  'A',
#  'C',
#  'D',
#  'D',
#  'B',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'A',
#  'C',
#  'D',
#  'C',
#  'C',
#  'D',
#  'A',
#  'A',
#  'C',
#  'B',
#  'A',
#  'B',
#  'D',
#  'C',
#  'B',
#  'D',
#  'D',
#  'C',
#  'C',
#  'B',
#  'B',
#  'A',
#  'B',
#  'C',
#  'A',
#  'B',
#  'C',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'C',
#  'C',
#  'C',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'D',
#  'A',
#  'A',
#  'C',
#  'D',
#  'C',
#  'B',
#  'A',
#  'B',
#  'A',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
#  'D',
#  'D',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'A',
#  'C',
#  'A',
#  'B',
#  'D',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'D',
#  'D',
#  'B',
#  'D',
#  'B',
#  'C',
#  'B',
#  'D',
#  'D',
#  'D',
#  'C',
#  'D',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'A',
#  'B',
#  'B',
#  'C',
#  'C',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'D',
#  'A',
#  'C',
#  'D',
#  'B',
#  'D',
#  'D',
#  'D',
#  'C',
#  'C',
#  'D',
#  'B',
#  'D',
#  'C',
#  'C',
#  'D',
#  'C',
#  'C',
#  'A',
#  'B',
#  'C',
#  'D',
#  'D',
#  'A',
#  'B',
#  'C',
#  'D',
#  'B',
#  'A',
#  'D',
#  'B',
#  'D',
#  'A',
#  'D',
#  'D',
#  'A',
#  'C',
#  'A',
#  'D',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'D',
#  'B',
#  'D',
#  'B',
#  'D',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'C',
#  'D',
#  'A',
#  'A',
#  'B',
#  'D',
#  'D',
#  'D',
#  'A',
#  'D',
#  'D',
#  'A',
#  'D',
#  'D',
#  'D',
#  'A',
#  'B',
#  'B',
#  'B',
#  'C',
#  'B',
#  'C',
#  'A',
#  'D',
#  'A',
#  'A',
#  'C',
#  'B',
#  'A',
#  'C',
#  'B',
#  'D',
#  'B',
#  'D',
#  'D',
#  'C',
#  'A',
#  'D',
#  'B',
#  'B',
#  'D',
#  'D',
#  'B',
#  'D',
#  'A',
#  'C',
#  'D',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'A',
#  'C',
#  'C',
#  'A',
#  'C',
#  'A',
#  'C',
#  'A',
#  'D',
#  'C',
#  'B',
#  'B',
#  'A',
#  'C',
#  'C',
#  'A',
#  'A',
#  'D',
#  'C',
#  'C',
#  'A',
#  'B',
#  'A',
#  'D',
#  'A',
#  'D',
#  'B',
#  'D',
#  'D',
#  'B',
#  'D',
#  'A',
#  'B',
#  'D',
#  'B',
#  'A',
#  'A',
#  'B',
#  'D',
#  'D',
#  'C',
#  'A',
#  'C',
#  'D',
#  'A',
#  'B']

# %%
categorical_col = pd.DataFrame(data=a, columns=['Group'])

# %%
diabetes = pd.concat([diabetes,categorical_col], axis=1)

# %%
diabetes.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome Group Group
# 0                  0.234415   50        1     B     B
# 1                  0.116567   31        0     B     B
# 2                  0.253629   32        1     B     C
# 3                  0.038002   21        0     C     A
# 4                  0.943638   33        1     C     A

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'Group', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min()) / (x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome Group Group
# 0                  0.234415   50        1     B     B
# 1                  0.116567   31        0     B     B
# 2                  0.253629   32        1     B     C
# 3                  0.038002   21        0     C     A
# 4                  0.943638   33        1     C     A

# %%
num_preg = tf.feature_column.numeric_column(key = 'Pregnancies', shape=[1])
glucose = tf.feature_column.numeric_column(key = 'Glucose', shape=[1])
blood_pressure = tf.feature_column.numeric_column(key = 'BloodPressure', shape=[1])
skin_thickness = tf.feature_column.numeric_column(key = 'SkinThickness', shape=[1])
insulin = tf.feature_column.numeric_column(key = 'Insulin', shape=[1])
bmi = tf.feature_column.numeric_column(key = 'BMI', shape=[1])
diabetes_pedigree_function = tf.feature_column.numeric_column(key = 'DiabetesPedigreeFunction', shape=[1])
age = tf.feature_column.numeric_column(key = 'Age', shape=[1])

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg, glucose, blood_pressure, skin_thickness, insulin, bmi, diabetes_pedigree_function,assigned_group, age_bucket]

# %%
x_data = diabetes.drop('Outcome', axis=1)

# %%
x_data.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age Group Group
# 0                  0.234415   50     B     B
# 1                  0.116567   31     B     B
# 2                  0.253629   32     B     C
# 3                  0.038002   21     C     A
# 4                  0.943638   33     C     A

# %%
labels = diabetes['Outcome']

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, labels, test_size =0.3, random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x = x_train, y= y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASUSPC~1\AppData\Local\Temp\tmpw4rzikjy
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\ASUSPC~1\\AppData\\Local\\Temp\\tmpw4rzikjy', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000017117333588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.InvalidArgumentError'>, Shape mismatch in tuple component 9. Expected [10], got [10,2]
# 	 [[Node: enqueue_input/random_shuffle_queue_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT64, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_INT64, DT_STRING, DT_STRING, DT_INT64], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](enqueue_input/random_shuffle_queue, _arg_enqueue_input/Placeholder_0_0, _arg_enqueue_input/Placeholder_1_0_3, _arg_enqueue_input/Placeholder_2_0_4, _arg_enqueue_input/Placeholder_3_0_5, _arg_enqueue_input/Placeholder_4_0_6, _arg_enqueue_input/Placeholder_5_0_7, _arg_enqueue_input/Placeholder_6_0_8, _arg_enqueue_input/Placeholder_7_0_9, _arg_enqueue_input/Placeholder_8_0_10, _arg_enqueue_input/Placeholder_9_0_11, _arg_enqueue_input/Placeholder_10_0_1, _arg_enqueue_input/Placeholder_11_0_2)]]
#
# Caused by op 'enqueue_input/random_shuffle_queue_EnqueueMany', defined at:
#   File "C:\Users\ASUS PC\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ASUS PC\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-103-63ef68a9e6fb>", line 1, in <module>
#     model.train(input_fn=input_func, steps=1000)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 363, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 843, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 853, in _train_model_default
#     input_fn, model_fn_lib.ModeKeys.TRAIN))
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 691, in _get_features_and_labels_from_input_fn
#     result = self._call_input_fn(input_fn, mode)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 798, in _call_input_fn
#     return input_fn(**kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\pandas_io.py", line 110, in input_fn
#     num_epochs=num_epochs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py", line 473, in _enqueue_data
#     enqueue_ops.append(queue.enqueue_many(placeholders))
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 391, in enqueue_many
#     self._queue_ref, vals, name=scope)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 4297, in queue_enqueue_many_v2
#     timeout_ms=timeout_ms, name=name)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Shape mismatch in tuple component 9. Expected [10], got [10,2]
# 	 [[Node: enqueue_input/random_shuffle_queue_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT64, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_INT64, DT_STRING, DT_STRING, DT_INT64], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](enqueue_input/random_shuffle_queue, _arg_enqueue_input/Placeholder_0_0, _arg_enqueue_input/Placeholder_1_0_3, _arg_enqueue_input/Placeholder_2_0_4, _arg_enqueue_input/Placeholder_3_0_5, _arg_enqueue_input/Placeholder_4_0_6, _arg_enqueue_input/Placeholder_5_0_7, _arg_enqueue_input/Placeholder_6_0_8, _arg_enqueue_input/Placeholder_7_0_9, _arg_enqueue_input/Placeholder_8_0_10, _arg_enqueue_input/Placeholder_9_0_11, _arg_enqueue_input/Placeholder_10_0_1, _arg_enqueue_input/Placeholder_11_0_2)]]
#
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\ASUSPC~1\AppData\Local\Temp\tmpw4rzikjy\model.ckpt.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# InvalidArgumentError: Shape mismatch in tuple component 9. Expected [10], got [10,2]
# 	 [[Node: enqueue_input/random_shuffle_queue_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT64, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_INT64, DT_STRING, DT_STRING, DT_INT64], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](enqueue_input/random_shuffle_queue, _arg_enqueue_input/Placeholder_0_0, _arg_enqueue_input/Placeholder_1_0_3, _arg_enqueue_input/Placeholder_2_0_4, _arg_enqueue_input/Placeholder_3_0_5, _arg_enqueue_input/Placeholder_4_0_6, _arg_enqueue_input/Placeholder_5_0_7, _arg_enqueue_input/Placeholder_6_0_8, _arg_enqueue_input/Placeholder_7_0_9, _arg_enqueue_input/Placeholder_8_0_10, _arg_enqueue_input/Placeholder_9_0_11, _arg_enqueue_input/Placeholder_10_0_1, _arg_enqueue_input/Placeholder_11_0_2)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-103-63ef68a9e6fb> in <module>()
# ----> 1 model.train(input_fn=input_func, steps=1000)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     361
#     362     saving_listeners = _check_listeners_type(saving_listeners)
# --> 363     loss = self._train_model(input_fn, hooks, saving_listeners)
#     364     logging.info('Loss for final step: %s.', loss)
#     365     return self
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     841       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#     842     else:
# --> 843       return self._train_model_default(input_fn, hooks, saving_listeners)
#     844
#     845   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#     857       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#     858                                              hooks, global_step_tensor,
# --> 859                                              saving_listeners)
#     860
#     861   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1057       loss = None
#    1058       while not mon_sess.should_stop():
# -> 1059         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1060     return loss
#    1061
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in __exit__(self, exception_type, exception_value, traceback)
#     677     if exception_type in [errors.OutOfRangeError, StopIteration]:
#     678       exception_type = None
# --> 679     self._close_internal(exception_type)
#     680     # __exit__ should return True to suppress an exception.
#     681     return exception_type is None
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in _close_internal(self, exception_type)
#     714         if self._sess is None:
#     715           raise RuntimeError('Session is already closed.')
# --> 716         self._sess.close()
#     717       finally:
#     718         self._sess = None
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in close(self)
#     962     if self._sess:
#     963       try:
# --> 964         self._sess.close()
#     965       except _PREEMPTION_ERRORS:
#     966         pass
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in close(self)
#    1106       self._coord.join(
#    1107           stop_grace_period_secs=self._stop_grace_period_secs,
# -> 1108           ignore_live_threads=True)
#    1109     finally:
#    1110       try:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\coordinator.py in join(self, threads, stop_grace_period_secs, ignore_live_threads)
#     387       self._registered_threads = set()
#     388       if self._exc_info_to_raise:
# --> 389         six.reraise(*self._exc_info_to_raise)
#     390       elif stragglers:
#     391         if ignore_live_threads:
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py in _run(self, sess, enqueue_op, feed_fn, coord)
#      92         try:
#      93           feed_dict = None if feed_fn is None else feed_fn()
# ---> 94           sess.run(enqueue_op, feed_dict=feed_dict)
#      95         except (errors.OutOfRangeError, errors.CancelledError):
#      96           # This exception indicates that a queue was closed.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# InvalidArgumentError: Shape mismatch in tuple component 9. Expected [10], got [10,2]
# 	 [[Node: enqueue_input/random_shuffle_queue_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT64, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_INT64, DT_STRING, DT_STRING, DT_INT64], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](enqueue_input/random_shuffle_queue, _arg_enqueue_input/Placeholder_0_0, _arg_enqueue_input/Placeholder_1_0_3, _arg_enqueue_input/Placeholder_2_0_4, _arg_enqueue_input/Placeholder_3_0_5, _arg_enqueue_input/Placeholder_4_0_6, _arg_enqueue_input/Placeholder_5_0_7, _arg_enqueue_input/Placeholder_6_0_8, _arg_enqueue_input/Placeholder_7_0_9, _arg_enqueue_input/Placeholder_8_0_10, _arg_enqueue_input/Placeholder_9_0_11, _arg_enqueue_input/Placeholder_10_0_1, _arg_enqueue_input/Placeholder_11_0_2)]]
#
# Caused by op 'enqueue_input/random_shuffle_queue_EnqueueMany', defined at:
#   File "C:\Users\ASUS PC\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ASUS PC\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-103-63ef68a9e6fb>", line 1, in <module>
#     model.train(input_fn=input_func, steps=1000)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 363, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 843, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 853, in _train_model_default
#     input_fn, model_fn_lib.ModeKeys.TRAIN))
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 691, in _get_features_and_labels_from_input_fn
#     result = self._call_input_fn(input_fn, mode)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\estimator.py", line 798, in _call_input_fn
#     return input_fn(**kwargs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\pandas_io.py", line 110, in input_fn
#     num_epochs=num_epochs)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py", line 473, in _enqueue_data
#     enqueue_ops.append(queue.enqueue_many(placeholders))
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\ops\data_flow_ops.py", line 391, in enqueue_many
#     self._queue_ref, vals, name=scope)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py", line 4297, in queue_enqueue_many_v2
#     timeout_ms=timeout_ms, name=name)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "C:\Users\ASUS PC\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Shape mismatch in tuple component 9. Expected [10], got [10,2]
# 	 [[Node: enqueue_input/random_shuffle_queue_EnqueueMany = QueueEnqueueManyV2[Tcomponents=[DT_INT64, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_DOUBLE, DT_INT64, DT_STRING, DT_STRING, DT_INT64], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/device:CPU:0"](enqueue_input/random_shuffle_queue, _arg_enqueue_input/Placeholder_0_0, _arg_enqueue_input/Placeholder_1_0_3, _arg_enqueue_input/Placeholder_2_0_4, _arg_enqueue_input/Placeholder_3_0_5, _arg_enqueue_input/Placeholder_4_0_6, _arg_enqueue_input/Placeholder_5_0_7, _arg_enqueue_input/Placeholder_6_0_8, _arg_enqueue_input/Placeholder_7_0_9, _arg_enqueue_input/Placeholder_8_0_10, _arg_enqueue_input/Placeholder_9_0_11, _arg_enqueue_input/Placeholder_10_0_1, _arg_enqueue_input/Placeholder_11_0_2)]]
